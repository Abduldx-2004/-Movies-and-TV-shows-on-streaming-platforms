# %% [markdown]
# <div class="alert alert-warning">
# <h1><strong>🍿Movies and TV shows on streaming platforms</strong></h1>
#     <h4>During the pandemic,the popularity of streaming platforms has soared immensely📈 <br><br>
#     Embracing the new normal,here's an EDA of the same.</h4>
# </div>

# %% [markdown]
# <div>
# <img src="https://cdn.technadu.com/wp-content/uploads/2020/04/Netflix-Amazon-Prime-Hulu-Disney-Plus-Logos.png" width="550"/>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Imports</strong></h3>
# </div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.image as mpimg
import math
import plotly.express as px
import plotly.graph_objects as go

from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)
from plotly.colors import n_colors
from plotly.subplots import make_subplots
from IPython.display import Image
from colorama import Fore, Back, Style
y_ = Fore.YELLOW
r_ = Fore.RED
g_ = Fore.GREEN
b_ = Fore.BLUE
m_ = Fore.MAGENTA
sr_ = Style.RESET_ALL

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Custom Color Palette</strong></h3>
# </div>

# %%
custom_colors = ["#ff6b6b","#95d5b2","#a2d2ff","#72efdd"]
customPalette = sns.set_palette(sns.color_palette(custom_colors))

# %%
sns.palplot(sns.color_palette(custom_colors),size=1)

# %% [markdown]
# > <h3>Netflix</h3>

# %%
netflix_p = sns.light_palette(custom_colors[0], reverse=True)
sns.palplot(sns.color_palette(netflix_p),size=1)

# %% [markdown]
# > <h3>Hulu</h3>

# %%
hulu_p = sns.light_palette(custom_colors[1], reverse=True)
sns.palplot(sns.color_palette(hulu_p),size=1)

# %% [markdown]
# > <h3>Prime Video</h3>

# %%
prime_p = sns.light_palette(custom_colors[2], reverse=True)
sns.palplot(sns.color_palette(prime_p),size=1)

# %% [markdown]
# > <h3>Disney+</h3>

# %%
disney_p = sns.dark_palette(custom_colors[3], reverse=True)
sns.palplot(sns.color_palette(disney_p),size=1)

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Loading the dataset and displaying rows</strong></h3>
# </div>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ruchi798/tv-shows-on-netflix-prime-video-hulu-and-disney")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\USER\.cache\kagglehub\datasets\ruchi798\tv-shows-on-netflix-prime-video-hulu-and-disney\versions\3

# %%
df_tv = pd.read_csv('tv_shows.csv')
df_movies = pd.read_csv('MoviesOnStreamingPlatforms_updated.csv')

# %%
df_tv = df_tv.drop(['Unnamed: 0'], axis = 1) 
df_tv.head(5)
# Out:
#    ID             Title  Year  Age    IMDb Rotten Tomatoes  Netflix  Hulu  \
# 0   1      Breaking Bad  2008  18+  9.4/10         100/100        1     0
# 1   2   Stranger Things  2016  16+  8.7/10          96/100        1     0
# 2   3   Attack on Titan  2013  18+  9.0/10          95/100        1     1
# 3   4  Better Call Saul  2015  18+  8.8/10          94/100        1     0
# 4   5              Dark  2017  16+  8.8/10          93/100        1     0
#
#    Prime Video  Disney+  Type
# 0            0        0     1
# 1            0        0     1
# 2            0        0     1
# 3            0        0     1
# 4            0        0     1

# %%
df_movies = df_movies.drop(['ID'], axis = 1) 
df_movies.reset_index(drop=True, inplace=True)
df_movies.head(5)
df_movies.isnull().sum()
df_movies['IMDb'].fillna(df_movies['IMDb'].mean(), inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3441159015.py:5: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %% [markdown]
# <h3> Number of unique directors for movies </h3>

# %%
len(df_movies['Directors'].unique())
# Out:
# 11339

# %% [markdown]
# <h3>Number of unique genres for movies </h3>

# %%
len(df_movies['Genres'].unique())
# Out:
# 1910

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Feature generation</strong></h3>
# </div>

# %%
def splitting(dataframe,col):
    result = dataframe[col].str.get_dummies(',')
    print('Done!')
    return result

# %%
m_genres = splitting(df_movies,'Genres')
m_lang = splitting(df_movies,'Language')
# Out:
# Done!
# Done!

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>TV shows and Movies per platform</strong></h3>
# </div>

# %%
def val_sum(df,c):
    return df[c].sum(axis=0)

# %%
val_counts = []
dfs = [df_movies,df_tv]
cols = ['Netflix','Hulu','Prime Video','Disney+']

for x in dfs:
    for y in cols:
        val_counts.append(val_sum(x,y))

# %%
val_counts
# Out:
# [3560.01, 903, 12354, 564, 1971, 1621, 1831, 351]

# %%
def donut(i,df,sizes,title):
    plt.subplot(i)
    plt.pie(sizes, explode=explode, labels=labels, colors=colors,
                autopct='%1.1f%%', shadow=True)

    centre_circle = plt.Circle((0,0),0.5,color='black', fc='white',linewidth=1.25)
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)
    plt.title(title)
    plt.axis('equal')

# %%
fig = plt.subplots(figsize=(16, 8))
labels = 'Netflix', 'Hulu','Prime','Disney+'
sizes1 = [val_counts[0], val_counts[1],val_counts[2],val_counts[3]]
sizes2 = [val_counts[4], val_counts[5],val_counts[6],val_counts[7]]
colors = custom_colors
explode = (0, 0, 0, 0) 

donut(121,df_movies,sizes1,'Movies')
donut(122,df_tv,sizes2,'TV shows')
plt.show()

# %% [markdown]
# <div>
# <h4><strong>📌 Prime has the maximum number of movies and Netflix has the maximum number of tv shows!</strong></h4>
# </div>

# %%
fig = make_subplots(rows=1, cols=2)

fig.add_trace(go.Indicator(
    mode = "number",
    value = 4113,
    number={'font':{'color': custom_colors[2],'size':100}},
    title = {"text": "Movies<br><span style='font-size:0.8em;color:gray'>On Prime Video</span>"},
    domain = {'x': [0, 0.5], 'y': [0.6, 1]}))

fig.add_trace(go.Indicator(
    mode = "number",
    value = 1971,
    number={'font':{'color': custom_colors[2],'size':100}},
    title = {"text": "TV Shows<br><span style='font-size:0.8em;color:gray'>On Netflix</span>"},
    domain = {'x': [0.5, 1], 'y': [0, 0.4]}))

fig.show()

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Movies with the highest IMDb rating on each platform and genres</strong></h3>
# </div>

# %%
df_movies['IMDb'] = df_movies['IMDb'].astype(str).str.split('/').str[0]
df_movies['Rotten Tomatoes'] = df_movies['Rotten Tomatoes'].astype(str).str.split('/').str[0]

df_tv['IMDb'] = df_tv['IMDb'].astype(str).str.split('/').str[0]
df_tv['Rotten Tomatoes'] = df_tv['Rotten Tomatoes'].astype(str).str.split('/').str[0]

# %%
def sunburst(dataframe,platform,c):
    dataframe=dataframe.loc[dataframe[platform] == 1]
    dataframe=dataframe.sort_values(by='IMDb', ascending=False)
    rating = dataframe[0:10]
    fig =px.sunburst(
    rating,
    path=['Title','Genres'],
    values='IMDb',
    color='IMDb',
    color_continuous_scale=c)
    fig.show()

# %%
sunburst(df_movies,'Netflix','amp')

# %%
sunburst(df_movies,'Hulu','Blugrn')

# %%
sunburst(df_movies,'Prime Video','haline')

# %%
sunburst(df_movies,'Disney+','dense')

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Distribution of runtime and release year of movies</strong></h3>
# </div>

# %%
def kde(i,dataframe,platform,c):
    plt.subplot(i)
    dataframe=dataframe.loc[dataframe[platform] == 1]
    sns.kdeplot(data=dataframe['Runtime'], color=custom_colors[c],shade=True)
    plt.xlabel('Runtime in minutes', fontsize = 15)
    plt.legend(fontsize = 15);
    plt.subplot(i+1)
    sns.kdeplot(data=dataframe['Year'], color=custom_colors[c],shade=True)
    plt.xlabel('Release Year', fontsize = 15)
    plt.legend(fontsize = 15);

# %%
plt.figure(figsize = (16, 8))

kde(421,df_movies,'Netflix',0)
kde(423,df_movies,'Hulu',1)
kde(425,df_movies,'Prime Video',2)
kde(427,df_movies,'Disney+',3)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:4: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:6: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:8: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:10: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:4: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:6: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:8: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:10: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:4: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:6: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:8: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:10: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:4: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:6: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:8: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\3343580252.py:10: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
post_1980 = df_movies[df_movies.Year >= 1980]
year_movies = post_1980.groupby('Year')[['Netflix','Hulu','Prime Video','Disney+']].sum()

plt.figure(figsize = (16, 8))
sns.lineplot(x=year_movies.index,y=year_movies['Netflix'])
sns.lineplot(x=year_movies.index,y=year_movies['Hulu'])
sns.lineplot(x=year_movies.index,y=year_movies['Prime Video'])
sns.lineplot(x=year_movies.index,y=year_movies['Disney+'])
plt.xlabel('Release Year', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>TV shows with minimum age requirement on each platform</strong></h3>
# </div>

# %%
df_t = df_tv.copy()
df_t = df_t[df_t['Age'].notna()]

# %%
df_t['Age']=df_t['Age'].str.replace('+','')
df_t['Age']=df_t['Age'].str.replace('all','0')
df_t['Age']=df_t['Age'].astype(str).astype(int)

# %%
def barplot(i,dataframe,platform,p):
    plt.subplot(i)
    dataframe=dataframe.loc[dataframe[platform] == 1]
    dataframe = dataframe['Age'].value_counts().reset_index()
    dataframe.columns=['age','count']
    sns.barplot(x="age", y="count", data=dataframe,palette=p)
    plt.xlabel('Age', fontsize = 15)
    plt.ylabel(platform, fontsize = 15)

# %%
plt.figure(figsize = (20, 20))

barplot(421,df_t,'Netflix',netflix_p)
barplot(423,df_t,'Hulu',hulu_p)
barplot(425,df_t,'Prime Video',prime_p)
barplot(427,df_t,'Disney+',disney_p)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\188731043.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\188731043.py:6: UserWarning:
#
# The palette list has more values (6) than needed (5), which may not be intended.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\188731043.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\188731043.py:6: UserWarning:
#
# The palette list has more values (6) than needed (5), which may not be intended.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\188731043.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\188731043.py:6: UserWarning:
#
# The palette list has more values (6) than needed (5), which may not be intended.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\188731043.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\188731043.py:6: UserWarning:
#
# The palette list has more values (6) than needed (4), which may not be intended.

# %%
plt.figure(figsize = (16, 8))
tv_age = df_t.groupby('Age')[['Netflix','Hulu','Prime Video','Disney+']].sum()
sns.heatmap(tv_age,cmap="YlGnBu")
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>TV shows with the highest IMDb rating vs availability</strong></h3>
# </div>

# %%
r = df_tv.sort_values(by='IMDb', ascending=False)
r = r[0:20]
r = r[['Title','IMDb','Netflix','Hulu','Prime Video','Disney+']]
r['IMDb'] = r['IMDb'].astype(float)

# %%
r.style.bar(subset=["Netflix"], color='#ff6b6b')\
.bar(subset=["Hulu"], color='#95d5b2')\
.bar(subset=["Prime Video"], color='#a2d2ff')\
.bar(subset=["Disney+"], color='#72efdd')\
.bar(subset=["IMDb"], color='#').background_gradient(cmap='Purples')
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\pandas\io\formats\style.py:4040: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# C:\Users\USER\anaconda3\Lib\site-packages\pandas\io\formats\style.py:4040: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# C:\Users\USER\anaconda3\Lib\site-packages\pandas\io\formats\style.py:4074: RuntimeWarning:
#
# All-NaN axis encountered
#
# C:\Users\USER\anaconda3\Lib\site-packages\pandas\io\formats\style.py:4075: RuntimeWarning:
#
# All-NaN axis encountered
#
# C:\Users\USER\anaconda3\Lib\site-packages\pandas\io\formats\style.py:3807: RuntimeWarning:
#
# All-NaN slice encountered
#
# C:\Users\USER\anaconda3\Lib\site-packages\pandas\io\formats\style.py:3808: RuntimeWarning:
#
# All-NaN slice encountered
# <style type="text/css">
# #T_f16ba_row0_col1, #T_f16ba_row1_col1, #T_f16ba_row2_col1, #T_f16ba_row3_col1, #T_f16ba_row4_col1, #T_f16ba_row5_col1, #T_f16ba_row6_col1, #T_f16ba_row7_col1, #T_f16ba_row8_col1, #T_f16ba_row9_col1, #T_f16ba_row10_col1, #T_f16ba_row11_col1, #T_f16ba_row12_col1, #T_f16ba_row13_col1, #T_f16ba_row14_col1, #T_f16ba_row15_col1, #T_f16ba_row16_col1, #T_f16ba_row17_col1, #T_f16ba_row18_col1, #T_f16ba_row19_col1 {
#   width: 10em;
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f16ba_row0_col2, #T_f16ba_row0_col3, #T_f16ba_row0_col4, #T_f16ba_row1_col2, #T_f16ba_row1_col3, #T_f16ba_row1_col5, #T_f16ba_row2_col2, #T_f16ba_row2_col3, #T_f16ba_row2_col5, #T_f16ba_row3_col2, #T_f16ba_row3_col3, #T_f16ba_row3_col5, #T_f16ba_row4_col2, #T_f16ba_row4_col3, #T_f16ba_row4_col5, #T_f16ba_row5_col2, #T_f16ba_row5_col3, #T_f16ba_row5_col5, #T_f16ba_row6_col2, #T_f16ba_row6_col3, #T_f16ba_row6_col5, #T_f16ba_row7_col2, #T_f16ba_row7_col3, #T_f16ba_row7_col5, #T_f16ba_row8_col2, #T_f16ba_row8_col3, #T_f16ba_row8_col5, #T_f16ba_row9_col2, #T_f16ba_row9_col3, #T_f16ba_row9_col5, #T_f16ba_row10_col2, #T_f16ba_row10_col3, #T_f16ba_row10_col5, #T_f16ba_row11_col2, #T_f16ba_row11_col3, #T_f16ba_row11_col5, #T_f16ba_row12_col2, #T_f16ba_row12_col3, #T_f16ba_row12_col5, #T_f16ba_row13_col2, #T_f16ba_row13_col3, #T_f16ba_row13_col5, #T_f16ba_row14_col2, #T_f16ba_row14_col3, #T_f16ba_row14_col5, #T_f16ba_row15_col2, #T_f16ba_row15_col3, #T_f16ba_row15_col5, #T_f16ba_row16_col2, #T_f16ba_row16_col3, #T_f16ba_row16_col5, #T_f16ba_row17_col2, #T_f16ba_row17_col3, #T_f16ba_row17_col5, #T_f16ba_row18_col2, #T_f16ba_row18_col3, #T_f16ba_row18_col5, #T_f16ba_row19_col2, #T_f16ba_row19_col3, #T_f16ba_row19_col5 {
#   width: 10em;
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_f16ba_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 100.0%, transparent 100.0%);
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_f16ba_row1_col4, #T_f16ba_row2_col4, #T_f16ba_row3_col4, #T_f16ba_row4_col4, #T_f16ba_row5_col4, #T_f16ba_row6_col4, #T_f16ba_row7_col4, #T_f16ba_row8_col4, #T_f16ba_row9_col4, #T_f16ba_row10_col4, #T_f16ba_row11_col4, #T_f16ba_row12_col4, #T_f16ba_row13_col4, #T_f16ba_row14_col4, #T_f16ba_row15_col4, #T_f16ba_row16_col4, #T_f16ba_row17_col4, #T_f16ba_row18_col4, #T_f16ba_row19_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 100.0%, transparent 100.0%);
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f16ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f16ba_level0_col0" class="col_heading level0 col0" >Title</th>
#       <th id="T_f16ba_level0_col1" class="col_heading level0 col1" >IMDb</th>
#       <th id="T_f16ba_level0_col2" class="col_heading level0 col2" >Netflix</th>
#       <th id="T_f16ba_level0_col3" class="col_heading level0 col3" >Hulu</th>
#       <th id="T_f16ba_level0_col4" class="col_heading level0 col4" >Prime Video</th>
#       <th id="T_f16ba_level0_col5" class="col_heading level0 col5" >Disney+</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f16ba_level0_row0" class="row_heading level0 row0" >5367</th>
#       <td id="T_f16ba_row0_col0" class="data row0 col0" >Fearless Adventures with Jack Randall</td>
#       <td id="T_f16ba_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_f16ba_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_f16ba_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f16ba_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f16ba_row0_col5" class="data row0 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f16ba_level0_row1" class="row_heading level0 row1" >4492</th>
#       <td id="T_f16ba_row1_col0" class="data row1 col0" >Color Inspirations: Art And Music</td>
#       <td id="T_f16ba_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_f16ba_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_f16ba_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_f16ba_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_f16ba_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f16ba_level0_row2" class="row_heading level0 row2" >4236</th>
#       <td id="T_f16ba_row2_col0" class="data row2 col0" >Ground Warfare</td>
#       <td id="T_f16ba_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_f16ba_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_f16ba_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_f16ba_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_f16ba_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f16ba_level0_row3" class="row_heading level0 row3" >4233</th>
#       <td id="T_f16ba_row3_col0" class="data row3 col0" >Faster with Finnegan</td>
#       <td id="T_f16ba_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_f16ba_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_f16ba_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_f16ba_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_f16ba_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f16ba_level0_row4" class="row_heading level0 row4" >4220</th>
#       <td id="T_f16ba_row4_col0" class="data row4 col0" >Pet Moms</td>
#       <td id="T_f16ba_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_f16ba_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_f16ba_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_f16ba_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_f16ba_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f16ba_level0_row5" class="row_heading level0 row5" >4219</th>
#       <td id="T_f16ba_row5_col0" class="data row5 col0" >Great Family Adventures</td>
#       <td id="T_f16ba_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_f16ba_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_f16ba_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_f16ba_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_f16ba_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f16ba_level0_row6" class="row_heading level0 row6" >4218</th>
#       <td id="T_f16ba_row6_col0" class="data row6 col0" >Luxury Life</td>
#       <td id="T_f16ba_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_f16ba_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_f16ba_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_f16ba_row6_col4" class="data row6 col4" >1</td>
#       <td id="T_f16ba_row6_col5" class="data row6 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f16ba_level0_row7" class="row_heading level0 row7" >4217</th>
#       <td id="T_f16ba_row7_col0" class="data row7 col0" >Underground: La Historia del Reggeaton</td>
#       <td id="T_f16ba_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_f16ba_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_f16ba_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_f16ba_row7_col4" class="data row7 col4" >1</td>
#       <td id="T_f16ba_row7_col5" class="data row7 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f16ba_level0_row8" class="row_heading level0 row8" >4216</th>
#       <td id="T_f16ba_row8_col0" class="data row8 col0" >DNA Detectives</td>
#       <td id="T_f16ba_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_f16ba_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_f16ba_row8_col3" class="data row8 col3" >0</td>
#       <td id="T_f16ba_row8_col4" class="data row8 col4" >1</td>
#       <td id="T_f16ba_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f16ba_level0_row9" class="row_heading level0 row9" >4215</th>
#       <td id="T_f16ba_row9_col0" class="data row9 col0" >Legends of Power with Tony Robinson</td>
#       <td id="T_f16ba_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_f16ba_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_f16ba_row9_col3" class="data row9 col3" >0</t

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Movies with the highest IMDb rating, genres and languages</strong></h3>
# </div>

# %%
r1 = df_movies.sort_values(by='IMDb', ascending=False)
r1 = r1[0:10]
r1['Movies']='Movies'
fig = px.treemap(r1, path=['Movies','Title', 'Genres','Language'], values='IMDb',color='IMDb',color_continuous_scale='Purp')
fig.show()

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Movies with the highest Rotten Tomatoes rating vs directors</strong></h3>
# </div>

# %%
df_m = df_movies.copy()
df_m = df_m.dropna()

df_m['Rotten Tomatoes'] = df_m['Rotten Tomatoes'].str.replace('%', '', regex=False)
df_m['Rotten Tomatoes'] = pd.to_numeric(df_m['Rotten Tomatoes'], errors='coerce')
df_m = df_m.dropna(subset=['Rotten Tomatoes'])
df_m['Rotten Tomatoes'] = df_m['Rotten Tomatoes'].astype(int)

df_m['Directors'] = df_m['Directors'].astype(str)

# %%
df_m=df_m.sort_values(by='Rotten Tomatoes', ascending=False)
rating = df_m[0:20]
sns.catplot(x="Rotten Tomatoes", y="Directors",data=rating, palette=netflix_p,height=7,kind="point");
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\1922662872.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\1922662872.py:3: UserWarning:
#
#
# The palette list has fewer values (6) than needed (20) and will cycle, which may produce an uninterpretable plot.

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Distribution of IMDb and Rotten Tomatoes ratings of movies on all platforms</strong></h3>
# </div>

# %%
def dist(i,dataframe,platform,c):
    plt.subplot(i)
    dataframe=dataframe.loc[dataframe[platform] == 1]
    sns.distplot(dataframe['IMDb'], color=custom_colors[c],vertical=True)
    
    plt.ylabel('IMDb rating, '+platform, fontsize = 15)
    plt.subplot(i+1)
    sns.distplot(dataframe['Rotten Tomatoes'], color=custom_colors[c],vertical=True)
    plt.ylabel('Rotten Tomatoes, '+platform, fontsize = 15)

# %%
plt.figure(figsize = (20, 20))

dist(421,df_m,'Netflix',0)
dist(423,df_m,'Hulu',1)
dist(425,df_m,'Prime Video',2)
dist(427,df_m,'Disney+',3)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\2315164553.py:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\2315164553.py:8: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\2315164553.py:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\2315164553.py:8: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\2315164553.py:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\2315164553.py:8: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\2315164553.py:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_9800\2315164553.py:8: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
df_m['Rotten Tomatoes'] = df_m['Rotten Tomatoes'].astype(float)
df_m['IMDb'] = df_m['IMDb'].astype(float)

plt.figure(figsize = (16, 8))
sns.regplot(x = df_m['Rotten Tomatoes'],y = df_m['IMDb'],x_bins=10,marker="+",color="#FDE74C")
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Languages and genres of movies on all platforms</strong></h3>
# </div>

# %%
df_l_merged = pd.concat([df_movies, m_lang], axis = 1, sort = False)
df_g_merged = pd.concat([df_movies, m_genres], axis = 1, sort = False)

# %%
def bar(dataframe,platform,c):
    dataframe=dataframe.loc[dataframe[platform] == 1]
    val_counts = dataframe.iloc[:,15:].sum(axis=0).sort_values(ascending=False)
    val_counts2 = pd.DataFrame(val_counts,columns=['Number of movies'])
    return val_counts2[0:20].style.bar(subset=["Number of movies",], color=c)

# %% [markdown]
# <div>
# <img src="https://download.logo.wine/logo/Netflix/Netflix-Logo.wine.png" width="350"/>
# </div>

# %%
bar(df_l_merged,'Netflix','#ff6b6b')
# Out:
# <style type="text/css">
# #T_fee1b_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 100.0%, transparent 100.0%);
# }
# #T_fee1b_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 16.6%, transparent 16.6%);
# }
# #T_fee1b_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 14.7%, transparent 14.7%);
# }
# #T_fee1b_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 9.4%, transparent 9.4%);
# }
# #T_fee1b_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 4.7%, transparent 4.7%);
# }
# #T_fee1b_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 4.0%, transparent 4.0%);
# }
# #T_fee1b_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 3.9%, transparent 3.9%);
# }
# #T_fee1b_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 3.7%, transparent 3.7%);
# }
# #T_fee1b_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 3.0%, transparent 3.0%);
# }
# #T_fee1b_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 2.6%, transparent 2.6%);
# }
# #T_fee1b_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 2.5%, transparent 2.5%);
# }
# #T_fee1b_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 2.4%, transparent 2.4%);
# }
# #T_fee1b_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 2.3%, transparent 2.3%);
# }
# #T_fee1b_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 2.1%, transparent 2.1%);
# }
# #T_fee1b_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 2.0%, transparent 2.0%);
# }
# #T_fee1b_row15_col0, #T_fee1b_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 1.9%, transparent 1.9%);
# }
# #T_fee1b_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 1.8%, transparent 1.8%);
# }
# #T_fee1b_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 1.7%, transparent 1.7%);
# }
# #T_fee1b_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 1.6%, transparent 1.6%);
# }
# </style>
# <table id="T_fee1b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fee1b_level0_col0" class="col_heading level0 col0" >Number of movies</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fee1b_level0_row0" class="row_heading level0 row0" >English</th>
#       <td id="T_fee1b_row0_col0" class="data row0 col0" >2263</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row1" class="row_heading level0 row1" >Hindi</th>
#       <td id="T_fee1b_row1_col0" class="data row1 col0" >376</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row2" class="row_heading level0 row2" >Spanish</th>
#       <td id="T_fee1b_row2_col0" class="data row2 col0" >332</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row3" class="row_heading level0 row3" >French</th>
#       <td id="T_fee1b_row3_col0" class="data row3 col0" >212</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row4" class="row_heading level0 row4" >German</th>
#       <td id="T_fee1b_row4_col0" class="data row4 col0" >106</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row5" class="row_heading level0 row5" >Japanese</th>
#       <td id="T_fee1b_row5_col0" class="data row5 col0" >91</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row6" class="row_heading level0 row6" >Arabic</th>
#       <td id="T_fee1b_row6_col0" class="data row6 col0" >89</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row7" class="row_heading level0 row7" >Mandarin</th>
#       <td id="T_fee1b_row7_col0" class="data row7 col0" >83</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row8" class="row_heading level0 row8" >Italian</th>
#       <td id="T_fee1b_row8_col0" class="data row8 col0" >67</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row9" class="row_heading level0 row9" >Turkish</th>
#       <td id="T_fee1b_row9_col0" class="data row9 col0" >58</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row10" class="row_heading level0 row10" >Cantonese</th>
#       <td id="T_fee1b_row10_col0" class="data row10 col0" >56</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row11" class="row_heading level0 row11" >Russian</th>
#       <td id="T_fee1b_row11_col0" class="data row11 col0" >54</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row12" class="row_heading level0 row12" >Tamil</th>
#       <td id="T_fee1b_row12_col0" class="data row12 col0" >52</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row13" class="row_heading level0 row13" >Punjabi</th>
#       <td id="T_fee1b_row13_col0" class="data row13 col0" >47</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row14" class="row_heading level0 row14" >Portuguese</th>
#       <td id="T_fee1b_row14_col0" class="data row14 col0" >45</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row15" class="row_heading level0 row15" >Indonesian</th>
#       <td id="T_fee1b_row15_col0" class="data row15 col0" >43</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row16" class="row_heading level0 row16" >Malayalam</th>
#       <td id="T_fee1b_row16_col0" class="data row16 col0" >42</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row17" class="row_heading level0 row17" >Filipino</th>
#       <td id="T_fee1b_row17_col0" class="data row17 col0" >40</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row18" class="row_heading level0 row18" >Korean</th>
#       <td id="T_fee1b_row18_col0" class="data row18 col0" >39</td>
#     </tr>
#     <tr>
#       <th id="T_fee1b_level0_row19" class="row_heading level0 row19" >Marathi</th>
#       <td id="T_fee1b_row19_col0" class="data row19 col0" >36</td>
#     </tr>
#   </tbody>
# </table>

# %%
bar(df_g_merged,'Netflix','#ff6b6b')
# Out:
# <style type="text/css">
# #T_7f77a_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 100.0%, transparent 100.0%);
# }
# #T_7f77a_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 87.1%, transparent 87.1%);
# }
# #T_7f77a_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 43.5%, transparent 43.5%);
# }
# #T_7f77a_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 36.7%, transparent 36.7%);
# }
# #T_7f77a_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 36.3%, transparent 36.3%);
# }
# #T_7f77a_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 34.1%, transparent 34.1%);
# }
# #T_7f77a_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 24.8%, transparent 24.8%);
# }
# #T_7f77a_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 21.2%, transparent 21.2%);
# }
# #T_7f77a_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 21.0%, transparent 21.0%);
# }
# #T_7f77a_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 17.7%, transparent 17.7%);
# }
# #T_7f77a_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 17.2%, transparent 17.2%);
# }
# #T_7f77a_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 16.8%, transparent 16.8%);
# }
# #T_7f77a_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 14.8%, transparent 14.8%);
# }
# #T_7f77a_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 13.3%, transparent 13.3%);
# }
# #T_7f77a_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 12.9%, transparent 12.9%);
# }
# #T_7f77a_row15_col0, #T_7f77a_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 8.8%, transparent 8.8%);
# }
# #T_7f77a_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 7.3%, transparent 7.3%);
# }
# #T_7f77a_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 6.6%, transparent 6.6%);
# }
# #T_7f77a_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #ff6b6b 5.8%, transparent 5.8%);
# }
# </style>
# <table id="T_7f77a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f77a_level0_col0" class="col_heading level0 col0" >Number of movies</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f77a_level0_row0" class="row_heading level0 row0" >Drama</th>
#       <td id="T_7f77a_row0_col0" class="data row0 col0" >1500</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row1" class="row_heading level0 row1" >Comedy</th>
#       <td id="T_7f77a_row1_col0" class="data row1 col0" >1307</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row2" class="row_heading level0 row2" >Thriller</th>
#       <td id="T_7f77a_row2_col0" class="data row2 col0" >652</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row3" class="row_heading level0 row3" >Romance</th>
#       <td id="T_7f77a_row3_col0" class="data row3 col0" >551</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row4" class="row_heading level0 row4" >Action</th>
#       <td id="T_7f77a_row4_col0" class="data row4 col0" >545</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row5" class="row_heading level0 row5" >Documentary</th>
#       <td id="T_7f77a_row5_col0" class="data row5 col0" >511</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row6" class="row_heading level0 row6" >Crime</th>
#       <td id="T_7f77a_row6_col0" class="data row6 col0" >372</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row7" class="row_heading level0 row7" >Adventure</th>
#       <td id="T_7f77a_row7_col0" class="data row7 col0" >318</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row8" class="row_heading level0 row8" >Family</th>
#       <td id="T_7f77a_row8_col0" class="data row8 col0" >315</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row9" class="row_heading level0 row9" >Horror</th>
#       <td id="T_7f77a_row9_col0" class="data row9 col0" >266</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row10" class="row_heading level0 row10" >Fantasy</th>
#       <td id="T_7f77a_row10_col0" class="data row10 col0" >258</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row11" class="row_heading level0 row11" >Mystery</th>
#       <td id="T_7f77a_row11_col0" class="data row11 col0" >252</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row12" class="row_heading level0 row12" >Animation</th>
#       <td id="T_7f77a_row12_col0" class="data row12 col0" >222</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row13" class="row_heading level0 row13" >Biography</th>
#       <td id="T_7f77a_row13_col0" class="data row13 col0" >199</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row14" class="row_heading level0 row14" >Sci-Fi</th>
#       <td id="T_7f77a_row14_col0" class="data row14 col0" >194</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row15" class="row_heading level0 row15" >History</th>
#       <td id="T_7f77a_row15_col0" class="data row15 col0" >132</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row16" class="row_heading level0 row16" >Music</th>
#       <td id="T_7f77a_row16_col0" class="data row16 col0" >132</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row17" class="row_heading level0 row17" >Sport</th>
#       <td id="T_7f77a_row17_col0" class="data row17 col0" >110</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row18" class="row_heading level0 row18" >Short</th>
#       <td id="T_7f77a_row18_col0" class="data row18 col0" >99</td>
#     </tr>
#     <tr>
#       <th id="T_7f77a_level0_row19" class="row_heading level0 row19" >War</th>
#       <td id="T_7f77a_row19_col0" class="data row19 col0" >87</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Hulu_Logo.svg/1200px-Hulu_Logo.svg.png" width="300"/>
# </div>

# %%
bar(df_l_merged,'Hulu','#95d5b2')
# Out:
# <style type="text/css">
# #T_89e9b_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 100.0%, transparent 100.0%);
# }
# #T_89e9b_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 9.0%, transparent 9.0%);
# }
# #T_89e9b_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 8.1%, transparent 8.1%);
# }
# #T_89e9b_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 5.0%, transparent 5.0%);
# }
# #T_89e9b_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 4.3%, transparent 4.3%);
# }
# #T_89e9b_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 2.8%, transparent 2.8%);
# }
# #T_89e9b_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 2.2%, transparent 2.2%);
# }
# #T_89e9b_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 2.1%, transparent 2.1%);
# }
# #T_89e9b_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 2.0%, transparent 2.0%);
# }
# #T_89e9b_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 1.6%, transparent 1.6%);
# }
# #T_89e9b_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 1.5%, transparent 1.5%);
# }
# #T_89e9b_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 1.3%, transparent 1.3%);
# }
# #T_89e9b_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 1.2%, transparent 1.2%);
# }
# #T_89e9b_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 1.0%, transparent 1.0%);
# }
# #T_89e9b_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 0.7%, transparent 0.7%);
# }
# #T_89e9b_row15_col0, #T_89e9b_row16_col0, #T_89e9b_row17_col0, #T_89e9b_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 0.6%, transparent 0.6%);
# }
# #T_89e9b_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 0.5%, transparent 0.5%);
# }
# </style>
# <table id="T_89e9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89e9b_level0_col0" class="col_heading level0 col0" >Number of movies</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89e9b_level0_row0" class="row_heading level0 row0" >English</th>
#       <td id="T_89e9b_row0_col0" class="data row0 col0" >815</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row1" class="row_heading level0 row1" >French</th>
#       <td id="T_89e9b_row1_col0" class="data row1 col0" >73</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row2" class="row_heading level0 row2" >Spanish</th>
#       <td id="T_89e9b_row2_col0" class="data row2 col0" >66</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row3" class="row_heading level0 row3" >German</th>
#       <td id="T_89e9b_row3_col0" class="data row3 col0" >41</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row4" class="row_heading level0 row4" >Japanese</th>
#       <td id="T_89e9b_row4_col0" class="data row4 col0" >35</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row5" class="row_heading level0 row5" >Italian</th>
#       <td id="T_89e9b_row5_col0" class="data row5 col0" >23</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row6" class="row_heading level0 row6" >Russian</th>
#       <td id="T_89e9b_row6_col0" class="data row6 col0" >18</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row7" class="row_heading level0 row7" >Mandarin</th>
#       <td id="T_89e9b_row7_col0" class="data row7 col0" >17</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row8" class="row_heading level0 row8" >Korean</th>
#       <td id="T_89e9b_row8_col0" class="data row8 col0" >16</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row9" class="row_heading level0 row9" >Danish</th>
#       <td id="T_89e9b_row9_col0" class="data row9 col0" >13</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row10" class="row_heading level0 row10" >Arabic</th>
#       <td id="T_89e9b_row10_col0" class="data row10 col0" >12</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row11" class="row_heading level0 row11" >Swedish</th>
#       <td id="T_89e9b_row11_col0" class="data row11 col0" >11</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row12" class="row_heading level0 row12" >Chinese</th>
#       <td id="T_89e9b_row12_col0" class="data row12 col0" >10</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row13" class="row_heading level0 row13" >Latin</th>
#       <td id="T_89e9b_row13_col0" class="data row13 col0" >8</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row14" class="row_heading level0 row14" >Norwegian</th>
#       <td id="T_89e9b_row14_col0" class="data row14 col0" >6</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row15" class="row_heading level0 row15" >Portuguese</th>
#       <td id="T_89e9b_row15_col0" class="data row15 col0" >5</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row16" class="row_heading level0 row16" >Dutch</th>
#       <td id="T_89e9b_row16_col0" class="data row16 col0" >5</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row17" class="row_heading level0 row17" >Hebrew</th>
#       <td id="T_89e9b_row17_col0" class="data row17 col0" >5</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row18" class="row_heading level0 row18" >Klingon</th>
#       <td id="T_89e9b_row18_col0" class="data row18 col0" >5</td>
#     </tr>
#     <tr>
#       <th id="T_89e9b_level0_row19" class="row_heading level0 row19" >Polish</th>
#       <td id="T_89e9b_row19_col0" class="data row19 col0" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
bar(df_g_merged,'Hulu','#95d5b2')
# Out:
# <style type="text/css">
# #T_fb01b_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 100.0%, transparent 100.0%);
# }
# #T_fb01b_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 62.1%, transparent 62.1%);
# }
# #T_fb01b_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 50.5%, transparent 50.5%);
# }
# #T_fb01b_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 34.5%, transparent 34.5%);
# }
# #T_fb01b_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 30.1%, transparent 30.1%);
# }
# #T_fb01b_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 29.5%, transparent 29.5%);
# }
# #T_fb01b_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 28.3%, transparent 28.3%);
# }
# #T_fb01b_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 25.3%, transparent 25.3%);
# }
# #T_fb01b_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 24.0%, transparent 24.0%);
# }
# #T_fb01b_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 22.8%, transparent 22.8%);
# }
# #T_fb01b_row10_col0, #T_fb01b_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 19.6%, transparent 19.6%);
# }
# #T_fb01b_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 17.6%, transparent 17.6%);
# }
# #T_fb01b_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 17.1%, transparent 17.1%);
# }
# #T_fb01b_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 13.2%, transparent 13.2%);
# }
# #T_fb01b_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 8.7%, transparent 8.7%);
# }
# #T_fb01b_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 8.2%, transparent 8.2%);
# }
# #T_fb01b_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 6.2%, transparent 6.2%);
# }
# #T_fb01b_row18_col0, #T_fb01b_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #95d5b2 5.7%, transparent 5.7%);
# }
# </style>
# <table id="T_fb01b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb01b_level0_col0" class="col_heading level0 col0" >Number of movies</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb01b_level0_row0" class="row_heading level0 row0" >Drama</th>
#       <td id="T_fb01b_row0_col0" class="data row0 col0" >438</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row1" class="row_heading level0 row1" >Comedy</th>
#       <td id="T_fb01b_row1_col0" class="data row1 col0" >272</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row2" class="row_heading level0 row2" >Thriller</th>
#       <td id="T_fb01b_row2_col0" class="data row2 col0" >221</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row3" class="row_heading level0 row3" >Romance</th>
#       <td id="T_fb01b_row3_col0" class="data row3 col0" >151</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row4" class="row_heading level0 row4" >Documentary</th>
#       <td id="T_fb01b_row4_col0" class="data row4 col0" >132</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row5" class="row_heading level0 row5" >Action</th>
#       <td id="T_fb01b_row5_col0" class="data row5 col0" >129</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row6" class="row_heading level0 row6" >Horror</th>
#       <td id="T_fb01b_row6_col0" class="data row6 col0" >124</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row7" class="row_heading level0 row7" >Adventure</th>
#       <td id="T_fb01b_row7_col0" class="data row7 col0" >111</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row8" class="row_heading level0 row8" >Family</th>
#       <td id="T_fb01b_row8_col0" class="data row8 col0" >105</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row9" class="row_heading level0 row9" >Crime</th>
#       <td id="T_fb01b_row9_col0" class="data row9 col0" >100</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row10" class="row_heading level0 row10" >Mystery</th>
#       <td id="T_fb01b_row10_col0" class="data row10 col0" >86</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row11" class="row_heading level0 row11" >Sci-Fi</th>
#       <td id="T_fb01b_row11_col0" class="data row11 col0" >86</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row12" class="row_heading level0 row12" >Fantasy</th>
#       <td id="T_fb01b_row12_col0" class="data row12 col0" >77</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row13" class="row_heading level0 row13" >Animation</th>
#       <td id="T_fb01b_row13_col0" class="data row13 col0" >75</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row14" class="row_heading level0 row14" >Biography</th>
#       <td id="T_fb01b_row14_col0" class="data row14 col0" >58</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row15" class="row_heading level0 row15" >History</th>
#       <td id="T_fb01b_row15_col0" class="data row15 col0" >38</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row16" class="row_heading level0 row16" >Music</th>
#       <td id="T_fb01b_row16_col0" class="data row16 col0" >36</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row17" class="row_heading level0 row17" >Sport</th>
#       <td id="T_fb01b_row17_col0" class="data row17 col0" >27</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row18" class="row_heading level0 row18" >War</th>
#       <td id="T_fb01b_row18_col0" class="data row18 col0" >25</td>
#     </tr>
#     <tr>
#       <th id="T_fb01b_level0_row19" class="row_heading level0 row19" >Western</th>
#       <td id="T_fb01b_row19_col0" class="data row19 col0" >25</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div>
#
# <img src="https://logodownload.org/wp-content/uploads/2018/07/prime-video.png" width="300"/>
# </div>

# %%
bar(df_l_merged,'Prime Video','#a2d2ff')
# Out:
# <style type="text/css">
# #T_35fd6_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 100.0%, transparent 100.0%);
# }
# #T_35fd6_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 5.2%, transparent 5.2%);
# }
# #T_35fd6_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 4.9%, transparent 4.9%);
# }
# #T_35fd6_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 4.2%, transparent 4.2%);
# }
# #T_35fd6_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 3.5%, transparent 3.5%);
# }
# #T_35fd6_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 3.4%, transparent 3.4%);
# }
# #T_35fd6_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 2.7%, transparent 2.7%);
# }
# #T_35fd6_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 1.9%, transparent 1.9%);
# }
# #T_35fd6_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 1.6%, transparent 1.6%);
# }
# #T_35fd6_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 1.3%, transparent 1.3%);
# }
# #T_35fd6_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 1.2%, transparent 1.2%);
# }
# #T_35fd6_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 1.1%, transparent 1.1%);
# }
# #T_35fd6_row12_col0, #T_35fd6_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 0.9%, transparent 0.9%);
# }
# #T_35fd6_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 0.7%, transparent 0.7%);
# }
# #T_35fd6_row15_col0, #T_35fd6_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 0.6%, transparent 0.6%);
# }
# #T_35fd6_row17_col0, #T_35fd6_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 0.5%, transparent 0.5%);
# }
# #T_35fd6_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 0.4%, transparent 0.4%);
# }
# </style>
# <table id="T_35fd6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35fd6_level0_col0" class="col_heading level0 col0" >Number of movies</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35fd6_level0_row0" class="row_heading level0 row0" >English</th>
#       <td id="T_35fd6_row0_col0" class="data row0 col0" >10088</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row1" class="row_heading level0 row1" >French</th>
#       <td id="T_35fd6_row1_col0" class="data row1 col0" >522</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row2" class="row_heading level0 row2" >Spanish</th>
#       <td id="T_35fd6_row2_col0" class="data row2 col0" >493</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row3" class="row_heading level0 row3" >Hindi</th>
#       <td id="T_35fd6_row3_col0" class="data row3 col0" >424</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row4" class="row_heading level0 row4" >Italian</th>
#       <td id="T_35fd6_row4_col0" class="data row4 col0" >352</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row5" class="row_heading level0 row5" >German</th>
#       <td id="T_35fd6_row5_col0" class="data row5 col0" >341</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row6" class="row_heading level0 row6" >Mandarin</th>
#       <td id="T_35fd6_row6_col0" class="data row6 col0" >268</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row7" class="row_heading level0 row7" >Japanese</th>
#       <td id="T_35fd6_row7_col0" class="data row7 col0" >195</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row8" class="row_heading level0 row8" >Russian</th>
#       <td id="T_35fd6_row8_col0" class="data row8 col0" >157</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row9" class="row_heading level0 row9" >Cantonese</th>
#       <td id="T_35fd6_row9_col0" class="data row9 col0" >127</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row10" class="row_heading level0 row10" >Korean</th>
#       <td id="T_35fd6_row10_col0" class="data row10 col0" >126</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row11" class="row_heading level0 row11" >Tamil</th>
#       <td id="T_35fd6_row11_col0" class="data row11 col0" >113</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row12" class="row_heading level0 row12" >Telugu</th>
#       <td id="T_35fd6_row12_col0" class="data row12 col0" >92</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row13" class="row_heading level0 row13" >Arabic</th>
#       <td id="T_35fd6_row13_col0" class="data row13 col0" >90</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row14" class="row_heading level0 row14" >Hebrew</th>
#       <td id="T_35fd6_row14_col0" class="data row14 col0" >68</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row15" class="row_heading level0 row15" >Portuguese</th>
#       <td id="T_35fd6_row15_col0" class="data row15 col0" >61</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row16" class="row_heading level0 row16" >Swedish</th>
#       <td id="T_35fd6_row16_col0" class="data row16 col0" >58</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row17" class="row_heading level0 row17" >Dutch</th>
#       <td id="T_35fd6_row17_col0" class="data row17 col0" >47</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row18" class="row_heading level0 row18" >Latin</th>
#       <td id="T_35fd6_row18_col0" class="data row18 col0" >47</td>
#     </tr>
#     <tr>
#       <th id="T_35fd6_level0_row19" class="row_heading level0 row19" >Danish</th>
#       <td id="T_35fd6_row19_col0" class="data row19 col0" >44</td>
#     </tr>
#   </tbody>
# </table>

# %%
bar(df_g_merged,'Prime Video','#a2d2ff')
# Out:
# <style type="text/css">
# #T_4e91b_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 100.0%, transparent 100.0%);
# }
# #T_4e91b_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 55.3%, transparent 55.3%);
# }
# #T_4e91b_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 48.4%, transparent 48.4%);
# }
# #T_4e91b_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 37.7%, transparent 37.7%);
# }
# #T_4e91b_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 34.9%, transparent 34.9%);
# }
# #T_4e91b_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 34.5%, transparent 34.5%);
# }
# #T_4e91b_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 31.1%, transparent 31.1%);
# }
# #T_4e91b_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 26.2%, transparent 26.2%);
# }
# #T_4e91b_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 21.4%, transparent 21.4%);
# }
# #T_4e91b_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 18.1%, transparent 18.1%);
# }
# #T_4e91b_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 16.7%, transparent 16.7%);
# }
# #T_4e91b_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 13.3%, transparent 13.3%);
# }
# #T_4e91b_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 11.7%, transparent 11.7%);
# }
# #T_4e91b_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 10.5%, transparent 10.5%);
# }
# #T_4e91b_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 10.2%, transparent 10.2%);
# }
# #T_4e91b_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 9.0%, transparent 9.0%);
# }
# #T_4e91b_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 8.3%, transparent 8.3%);
# }
# #T_4e91b_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 8.2%, transparent 8.2%);
# }
# #T_4e91b_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 5.4%, transparent 5.4%);
# }
# #T_4e91b_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a2d2ff 4.8%, transparent 4.8%);
# }
# </style>
# <table id="T_4e91b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e91b_level0_col0" class="col_heading level0 col0" >Number of movies</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e91b_level0_row0" class="row_heading level0 row0" >Drama</th>
#       <td id="T_4e91b_row0_col0" class="data row0 col0" >5437</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row1" class="row_heading level0 row1" >Comedy</th>
#       <td id="T_4e91b_row1_col0" class="data row1 col0" >3004</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row2" class="row_heading level0 row2" >Thriller</th>
#       <td id="T_4e91b_row2_col0" class="data row2 col0" >2632</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row3" class="row_heading level0 row3" >Action</th>
#       <td id="T_4e91b_row3_col0" class="data row3 col0" >2049</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row4" class="row_heading level0 row4" >Documentary</th>
#       <td id="T_4e91b_row4_col0" class="data row4 col0" >1895</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row5" class="row_heading level0 row5" >Horror</th>
#       <td id="T_4e91b_row5_col0" class="data row5 col0" >1878</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row6" class="row_heading level0 row6" >Romance</th>
#       <td id="T_4e91b_row6_col0" class="data row6 col0" >1691</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row7" class="row_heading level0 row7" >Crime</th>
#       <td id="T_4e91b_row7_col0" class="data row7 col0" >1423</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row8" class="row_heading level0 row8" >Adventure</th>
#       <td id="T_4e91b_row8_col0" class="data row8 col0" >1166</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row9" class="row_heading level0 row9" >Mystery</th>
#       <td id="T_4e91b_row9_col0" class="data row9 col0" >983</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row10" class="row_heading level0 row10" >Sci-Fi</th>
#       <td id="T_4e91b_row10_col0" class="data row10 col0" >907</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row11" class="row_heading level0 row11" >Family</th>
#       <td id="T_4e91b_row11_col0" class="data row11 col0" >721</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row12" class="row_heading level0 row12" >Fantasy</th>
#       <td id="T_4e91b_row12_col0" class="data row12 col0" >635</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row13" class="row_heading level0 row13" >Biography</th>
#       <td id="T_4e91b_row13_col0" class="data row13 col0" >569</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row14" class="row_heading level0 row14" >History</th>
#       <td id="T_4e91b_row14_col0" class="data row14 col0" >552</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row15" class="row_heading level0 row15" >Music</th>
#       <td id="T_4e91b_row15_col0" class="data row15 col0" >487</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row16" class="row_heading level0 row16" >Western</th>
#       <td id="T_4e91b_row16_col0" class="data row16 col0" >450</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row17" class="row_heading level0 row17" >War</th>
#       <td id="T_4e91b_row17_col0" class="data row17 col0" >446</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row18" class="row_heading level0 row18" >Animation</th>
#       <td id="T_4e91b_row18_col0" class="data row18 col0" >296</td>
#     </tr>
#     <tr>
#       <th id="T_4e91b_level0_row19" class="row_heading level0 row19" >Short</th>
#       <td id="T_4e91b_row19_col0" class="data row19 col0" >262</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div>
# <img src="https://download.logo.wine/logo/Disney%2B/Disney%2B-Logo.wine.png" width="350"/>
# </div>

# %%
bar(df_l_merged,'Disney+','#72efdd')
# Out:
# <style type="text/css">
# #T_b1ddd_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 100.0%, transparent 100.0%);
# }
# #T_b1ddd_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 5.4%, transparent 5.4%);
# }
# #T_b1ddd_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 3.6%, transparent 3.6%);
# }
# #T_b1ddd_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 3.1%, transparent 3.1%);
# }
# #T_b1ddd_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 2.0%, transparent 2.0%);
# }
# #T_b1ddd_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 1.3%, transparent 1.3%);
# }
# #T_b1ddd_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 1.1%, transparent 1.1%);
# }
# #T_b1ddd_row7_col0, #T_b1ddd_row8_col0, #T_b1ddd_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 0.7%, transparent 0.7%);
# }
# #T_b1ddd_row10_col0, #T_b1ddd_row11_col0, #T_b1ddd_row12_col0, #T_b1ddd_row13_col0, #T_b1ddd_row14_col0, #T_b1ddd_row15_col0, #T_b1ddd_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 0.5%, transparent 0.5%);
# }
# #T_b1ddd_row17_col0, #T_b1ddd_row18_col0, #T_b1ddd_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 0.4%, transparent 0.4%);
# }
# </style>
# <table id="T_b1ddd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1ddd_level0_col0" class="col_heading level0 col0" >Number of movies</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1ddd_level0_row0" class="row_heading level0 row0" >English</th>
#       <td id="T_b1ddd_row0_col0" class="data row0 col0" >557</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row1" class="row_heading level0 row1" >French</th>
#       <td id="T_b1ddd_row1_col0" class="data row1 col0" >30</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row2" class="row_heading level0 row2" >Spanish</th>
#       <td id="T_b1ddd_row2_col0" class="data row2 col0" >20</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row3" class="row_heading level0 row3" >German</th>
#       <td id="T_b1ddd_row3_col0" class="data row3 col0" >17</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row4" class="row_heading level0 row4" >Italian</th>
#       <td id="T_b1ddd_row4_col0" class="data row4 col0" >11</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row5" class="row_heading level0 row5" >Mandarin</th>
#       <td id="T_b1ddd_row5_col0" class="data row5 col0" >7</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row6" class="row_heading level0 row6" >Japanese</th>
#       <td id="T_b1ddd_row6_col0" class="data row6 col0" >6</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row7" class="row_heading level0 row7" >Korean</th>
#       <td id="T_b1ddd_row7_col0" class="data row7 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row8" class="row_heading level0 row8" >Russian</th>
#       <td id="T_b1ddd_row8_col0" class="data row8 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row9" class="row_heading level0 row9" >Xhosa</th>
#       <td id="T_b1ddd_row9_col0" class="data row9 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row10" class="row_heading level0 row10" >Arabic</th>
#       <td id="T_b1ddd_row10_col0" class="data row10 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row11" class="row_heading level0 row11" >Hindi</th>
#       <td id="T_b1ddd_row11_col0" class="data row11 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row12" class="row_heading level0 row12" >Portuguese</th>
#       <td id="T_b1ddd_row12_col0" class="data row12 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row13" class="row_heading level0 row13" >Greek</th>
#       <td id="T_b1ddd_row13_col0" class="data row13 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row14" class="row_heading level0 row14" >Cantonese</th>
#       <td id="T_b1ddd_row14_col0" class="data row14 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row15" class="row_heading level0 row15" >Norwegian</th>
#       <td id="T_b1ddd_row15_col0" class="data row15 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row16" class="row_heading level0 row16" >Brazilian Sign Language</th>
#       <td id="T_b1ddd_row16_col0" class="data row16 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row17" class="row_heading level0 row17" >Swahili</th>
#       <td id="T_b1ddd_row17_col0" class="data row17 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row18" class="row_heading level0 row18" >Dutch</th>
#       <td id="T_b1ddd_row18_col0" class="data row18 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b1ddd_level0_row19" class="row_heading level0 row19" >Serbian</th>
#       <td id="T_b1ddd_row19_col0" class="data row19 col0" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
bar(df_g_merged,'Disney+','#72efdd')
# Out:
# <style type="text/css">
# #T_721c0_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 100.0%, transparent 100.0%);
# }
# #T_721c0_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 65.3%, transparent 65.3%);
# }
# #T_721c0_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 60.0%, transparent 60.0%);
# }
# #T_721c0_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 40.9%, transparent 40.9%);
# }
# #T_721c0_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 37.7%, transparent 37.7%);
# }
# #T_721c0_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 34.0%, transparent 34.0%);
# }
# #T_721c0_row6_col0, #T_721c0_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 20.5%, transparent 20.5%);
# }
# #T_721c0_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 19.5%, transparent 19.5%);
# }
# #T_721c0_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 18.1%, transparent 18.1%);
# }
# #T_721c0_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 14.7%, transparent 14.7%);
# }
# #T_721c0_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 9.1%, transparent 9.1%);
# }
# #T_721c0_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 7.7%, transparent 7.7%);
# }
# #T_721c0_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 5.6%, transparent 5.6%);
# }
# #T_721c0_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 5.3%, transparent 5.3%);
# }
# #T_721c0_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 4.9%, transparent 4.9%);
# }
# #T_721c0_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 4.2%, transparent 4.2%);
# }
# #T_721c0_row17_col0, #T_721c0_row18_col0, #T_721c0_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #72efdd 3.7%, transparent 3.7%);
# }
# </style>
# <table id="T_721c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_721c0_level0_col0" class="col_heading level0 col0" >Number of movies</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_721c0_level0_row0" class="row_heading level0 row0" >Family</th>
#       <td id="T_721c0_row0_col0" class="data row0 col0" >430</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row1" class="row_heading level0 row1" >Comedy</th>
#       <td id="T_721c0_row1_col0" class="data row1 col0" >281</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row2" class="row_heading level0 row2" >Adventure</th>
#       <td id="T_721c0_row2_col0" class="data row2 col0" >258</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row3" class="row_heading level0 row3" >Fantasy</th>
#       <td id="T_721c0_row3_col0" class="data row3 col0" >176</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row4" class="row_heading level0 row4" >Drama</th>
#       <td id="T_721c0_row4_col0" class="data row4 col0" >162</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row5" class="row_heading level0 row5" >Animation</th>
#       <td id="T_721c0_row5_col0" class="data row5 col0" >146</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row6" class="row_heading level0 row6" >Action</th>
#       <td id="T_721c0_row6_col0" class="data row6 col0" >88</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row7" class="row_heading level0 row7" >Sci-Fi</th>
#       <td id="T_721c0_row7_col0" class="data row7 col0" >88</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row8" class="row_heading level0 row8" >Musical</th>
#       <td id="T_721c0_row8_col0" class="data row8 col0" >84</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row9" class="row_heading level0 row9" >Romance</th>
#       <td id="T_721c0_row9_col0" class="data row9 col0" >78</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row10" class="row_heading level0 row10" >Documentary</th>
#       <td id="T_721c0_row10_col0" class="data row10 col0" >63</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row11" class="row_heading level0 row11" >Sport</th>
#       <td id="T_721c0_row11_col0" class="data row11 col0" >39</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row12" class="row_heading level0 row12" >Music</th>
#       <td id="T_721c0_row12_col0" class="data row12 col0" >33</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row13" class="row_heading level0 row13" >Crime</th>
#       <td id="T_721c0_row13_col0" class="data row13 col0" >24</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row14" class="row_heading level0 row14" >Short</th>
#       <td id="T_721c0_row14_col0" class="data row14 col0" >23</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row15" class="row_heading level0 row15" >Mystery</th>
#       <td id="T_721c0_row15_col0" class="data row15 col0" >21</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row16" class="row_heading level0 row16" >Biography</th>
#       <td id="T_721c0_row16_col0" class="data row16 col0" >18</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row17" class="row_heading level0 row17" >Thriller</th>
#       <td id="T_721c0_row17_col0" class="data row17 col0" >16</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row18" class="row_heading level0 row18" >Western</th>
#       <td id="T_721c0_row18_col0" class="data row18 col0" >16</td>
#     </tr>
#     <tr>
#       <th id="T_721c0_level0_row19" class="row_heading level0 row19" >History</th>
#       <td id="T_721c0_row19_col0" class="data row19 col0" >16</td>
#     </tr>
#   </tbody>
# </table>
